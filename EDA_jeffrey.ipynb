# %%
# !pip install pandas
# !pip install numpy
# Out:
# ...
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.1.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB 435.7 kB/s eta 0:00:30
#    ---------------------------------------- 0.1/12.9 MB 469.7 kB/s eta 0:00:28
#     --------------------------------------- 0.2/12.9 MB 1.3 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/12.9 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.2/12.9 MB 5.0 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
import numpy as np

# %%
file = "Zabbix_Events_nobreaklines(in).csv"

df = pd.read_csv(file, delimiter=',')
df.drop(columns=['recoverytime'], inplace=True)
df.head()
# Out:
#   event_datetime                                      event_host  \
# 0     2024/08/07      PZbekke04 5625266 VDSL site 3BETVBR542ASM1
# 1     2024/07/26   OUDSBERGENcam30 5602320 VDSL site 3OUNLIM419A
# 2     2024/07/26  PZKASTZEcam04.smvi.ciport.be 5602447 VDSL cam2
# 3     2024/07/26   OUDSBERGENcam30 5602320 VDSL site 3OUNLIM419A
# 4     2024/07/26   OUDSBERGENcam30 5602320 VDSL site 3OUNLIM419A
#
#                          host_dns  \
# 0                             NaN
# 1  OUDSBERGENcam30.smvi.ciport.be
# 2       Castecam04.smvi.ciport.be
# 3  OUDSBERGENcam30.smvi.ciport.be
# 4  OUDSBERGENcam30.smvi.ciport.be
#
#                                        event_trigger   event_id  \
# 0  Response time is too high on PZbekke04 5625266...  9246116.0
# 1  OUDSBERGENcam30 5602320 VDSL site 3OUNLIM419A ...  9027694.0
# 2  Response time is too high on PZKASTZEcam04.smv...  9027867.0
# 3  OUDSBERGENcam30 5602320 VDSL site 3OUNLIM419A ...  9027950.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9230 entries, 0 to 9229
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_datetime       9229 non-null   object
#  1   event_host           9209 non-null   object
#  2   host_dns             4673 non-null   object
#  3   event_trigger        9209 non-null   object
#  4   event_id             9209 non-null   float64
#  5   alert_subject        9209 non-null   object
#  6   alert_message        9209 non-null   object
#  7   event_nseverity      9209 non-null   float64
#  8   event_value          9209 non-null   float64
#  9   topdesk_issue_key    9209 non-null   object
#  10  topdesk_issue_link   9209 non-null   object
#  11  trigger_id           9209 non-null   float64
#  12  event_recovery_time  9193 non-null   object
#  13  event_recovery_date  9192 non-null   object
#  14  event_recovery_name  9193 non-null   object
# ...
